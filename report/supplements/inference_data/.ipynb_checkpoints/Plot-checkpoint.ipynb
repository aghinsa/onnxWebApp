# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import imgkit
from tabulate import tabulate

# %%
def process_df(csv_path):
    df=pd.read_csv(csv_path)
    df=df.drop(['mean','std','epoch_1'],axis=1)
    df['mean']=df.loc[:, df.columns != 'model'].mean(axis=1)
    df['std']=df.loc[:, df.columns != 'model'].std(axis=1)
    df.set_index('model',inplace=True)
    df.sort_index(inplace=True)
    return df

# %%
## parsing json and converting to dataframe
log_dir="./logged/"
logs = ['mobilenet_v1_224','ssd_mobileNet_v1_300','resnet_v1.5_224','ssd_resnet34_1200']
datas=[]
for log in logs:
    path_to_json=log_dir+log+".json"
    with open(path_to_json) as f:
        data = json.load(f)
    data.pop("output_data_tensors");
    inference_times=data.pop("inference_times")
    inference_times={
            f"epoch_{i}":x for i,x in enumerate(inference_times,1)
        }
    data['model']=log
    data.update(inference_times)
    datas.append(data)
df=pd.DataFrame(datas)
df.to_csv('dev5.csv')

# %%
df=process_df('dev5.csv').sort_values(by=['mean'])
print(tabulate(df[['mean','std']]))
# Out:
# --------------------  ----------  ----------
# ssd_resnet34_1200      -0.866667    0.718022
# resnet_v1.5_224       255.7        53.4747
# mobilenet_v1_224      323.9        61.7016
# ssd_mobileNet_v1_300  749.2       139.198
# --------------------  ----------  ----------

# %%
df
# Out:
#                       epoch_2  epoch_3  epoch_4  epoch_5  epoch_6  epoch_7  \
# model
# mobilenet_v1_224          234       47       48       44       43       41
# ssd_mobileNet_v1_300       71       76       75       75       75       75
# resnet_v1.5_224           113      115      113      114      116      113
# ssd_resnet34_1200        6643     6866     6715     6850     6723     6901
#
#                       epoch_8  epoch_9  epoch_10  epoch_11    ...      \
# model                                                         ...
# mobilenet_v1_224           42       39        38        41    ...
# ssd_mobileNet_v1_300       77       76        78        77    ...
# resnet_v1.5_224           114      111       113       112    ...
# ssd_resnet34_1200        6725     6804      6897      6697    ...
#
#                       epoch_23  epoch_24  epoch_25  epoch_26  epoch_27  \
# model
# mobilenet_v1_224            39        39        39        39        39
# ssd_mobileNet_v1_300        75        76        74        76        75
# resnet_v1.5_224            111       113       113       113       112
# ssd_resnet34_1200         6765      6771      6996      6771      6778
#
#                       epoch_28  epoch_29  epoch_30         mean        std
# model
# mobilenet_v1_224            39        41        38    46.896552  35.443345
# ssd_mobileNet_v1_300        75        75        75    75.206897   1.269790
# resnet_v1.5_224            112       111       114   112.379310   1.690007
# ssd_resnet34_1200         6834      6789      6677  6784.344828  83.367188
#
# [4 rows x 31 columns]

# %%
# plot grouped bar
dfs=[f"dev{x}.csv" for x in range(1,6)]
dfs = list(map(lambda x:( process_df(x)[['mean']],x.split('.')[0] ),dfs))

dfs=sorted(dfs,key=lambda x:x[0].loc['mobilenet_v1_224'][0])
dfs,devices= zip(*dfs)

per_device_means=list(map(lambda x:x[["mean"]].values.ravel().tolist(),dfs))
per_model_means = list(zip(*per_device_means))
means_df=pd.DataFrame(per_device_means,index=devices,columns=dfs[0].index.tolist())  
devices_df = means_df.transpose()

# %%
ax=means_df.plot(kind="bar",figsize=(12,6))
ax.set_xlabel('Device', fontweight='bold')
ax.set_ylabel('Mean Inference Time in milliseconds', fontweight='bold');
plt.savefig("model_grouped.png")

# %%
# Corr devices
cm = sns.light_palette("yellow", as_cmap=True)
corr = devices_df.corr()
corr.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col0 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col1 {
#             background-color:  #ffffe5;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col2 {
#             background-color:  #ffffe5;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col3 {
#             background-color:  #ffffe5;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col4 {
#             background-color:  #ffffe5;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col0 {
#             background-color:  #ffffd8;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col1 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col2 {
#             background-color:  #ffff02;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col3 {
#             background-color:  #ffff03;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col4 {
#             background-color:  #ffff02;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col0 {
#             background-color:  #ffffdb;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col1 {
#             background-color:  #ffff02;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col2 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col3 {
#             background-color:  #ffff01;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col4 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col0 {
#             background-color:  #ffffe5;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col1 {
#             background-color:  #ffff03;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col2 {
#             background-color:  #ffff01;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col3 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col4 {
#             background-color:  #ffff01;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col0 {
#             background-color:  #ffffdc;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col1 {
#             background-color:  #ffff02;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col2 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col3 {
#             background-color:  #ffff00;
#         }    #T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col4 {
#             background-color:  #ffff00;
#         }</style>
# <table id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8fe" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >dev1</th>
#         <th class="col_heading level0 col1" >dev3</th>
#         <th class="col_heading level0 col2" >dev5</th>
#         <th class="col_heading level0 col3" >dev4</th>
#         <th class="col_heading level0 col4" >dev2</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8felevel0_row0" class="row_heading level0 row0" >dev1</th>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col0" class="data row0 col0" >1</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col1" class="data row0 col1" >-0.692056</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col2" class="data row0 col2" >-0.713916</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col3" class="data row0 col3" >-0.801255</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow0_col4" class="data row0 col4" >-0.7254</td>
#     </tr>    <tr>
#         <th id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8felevel0_row1" class="row_heading level0 row1" >dev3</th>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col0" class="data row1 col0" >-0.692056</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col1" class="data row1 col1" >1</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col2" class="data row1 col2" >0.986368</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col3" class="data row1 col3" >0.974104</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow1_col4" class="data row1 col4" >0.98417</td>
#     </tr>    <tr>
#         <th id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8felevel0_row2" class="row_heading level0 row2" >dev5</th>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col0" class="data row2 col0" >-0.713916</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col1" class="data row2 col1" >0.986368</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col2" class="data row2 col2" >1</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col3" class="data row2 col3" >0.99097</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow2_col4" class="data row2 col4" >0.999807</td>
#     </tr>    <tr>
#         <th id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8felevel0_row3" class="row_heading level0 row3" >dev4</th>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col0" class="data row3 col0" >-0.801255</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col1" class="data row3 col1" >0.974104</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col2" class="data row3 col2" >0.99097</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col3" class="data row3 col3" >1</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow3_col4" class="data row3 col4" >0.993068</td>
#     </tr>    <tr>
#         <th id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8felevel0_row4" class="row_heading level0 row4" >dev2</th>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col0" class="data row4 col0" >-0.7254</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col1" class="data row4 col1" >0.98417</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col2" class="data row4 col2" >0.999807</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col3" class="data row4 col3" >0.993068</td>
#         <td id="T_65da31e2_4fb6_11ea_a9d9_b7398923d8ferow4_col4" class="data row4 col4" >1</td>
#     </tr></tbody>
# </table>

# %%
corr_matrix = devices_df.corr().abs()
corr_pairs = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False))
print(corr_pairs)
# Out:
# dev5  dev2    0.999807
# dev4  dev2    0.993068
# dev5  dev4    0.990970
# dev3  dev5    0.986368
#       dev2    0.984170
#       dev4    0.974104
# dev1  dev4    0.801255
#       dev2    0.725400
#       dev5    0.713916
#       dev3    0.692056
# dtype: float64

# %%
# Corr models
cm = sns.light_palette("orange", as_cmap=True)
corr = means_df.corr()
corr.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col0 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col1 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col2 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col3 {
#             background-color:  #fff6e5;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col0 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col1 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col2 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col3 {
#             background-color:  #fff5e3;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col0 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col1 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col2 {
#             background-color:  #ffa500;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col3 {
#             background-color:  #fff6e5;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col0 {
#             background-color:  #fff6e5;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col1 {
#             background-color:  #fff6e5;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col2 {
#             background-color:  #fff6e5;
#         }    #T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col3 {
#             background-color:  #ffa500;
#         }</style>
# <table id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8fe" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >mobilenet_v1_224</th>
#         <th class="col_heading level0 col1" >resnet_v1.5_224</th>
#         <th class="col_heading level0 col2" >ssd_mobileNet_v1_300</th>
#         <th class="col_heading level0 col3" >ssd_resnet34_1200</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8felevel0_row0" class="row_heading level0 row0" >mobilenet_v1_224</th>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col0" class="data row0 col0" >1</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col1" class="data row0 col1" >0.999344</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col2" class="data row0 col2" >0.999049</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow0_col3" class="data row0 col3" >-0.348606</td>
#     </tr>    <tr>
#         <th id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8felevel0_row1" class="row_heading level0 row1" >resnet_v1.5_224</th>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col0" class="data row1 col0" >0.999344</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col1" class="data row1 col1" >1</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col2" class="data row1 col2" >0.999155</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow1_col3" class="data row1 col3" >-0.336652</td>
#     </tr>    <tr>
#         <th id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8felevel0_row2" class="row_heading level0 row2" >ssd_mobileNet_v1_300</th>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col0" class="data row2 col0" >0.999049</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col1" class="data row2 col1" >0.999155</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col2" class="data row2 col2" >1</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow2_col3" class="data row2 col3" >-0.35617</td>
#     </tr>    <tr>
#         <th id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8felevel0_row3" class="row_heading level0 row3" >ssd_resnet34_1200</th>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col0" class="data row3 col0" >-0.348606</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col1" class="data row3 col1" >-0.336652</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col2" class="data row3 col2" >-0.35617</td>
#         <td id="T_65fc538a_4fb6_11ea_a9d9_b7398923d8ferow3_col3" class="data row3 col3" >1</td>
#     </tr></tbody>
# </table>

# %%
corr_matrix = means_df.corr().abs()
corr_pairs = (corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
                 .stack()
                 .sort_values(ascending=False))
print(corr_pairs)
# Out:
# mobilenet_v1_224      resnet_v1.5_224         0.999344
# resnet_v1.5_224       ssd_mobileNet_v1_300    0.999155
# mobilenet_v1_224      ssd_mobileNet_v1_300    0.999049
# ssd_mobileNet_v1_300  ssd_resnet34_1200       0.356170
# mobilenet_v1_224      ssd_resnet34_1200       0.348606
# resnet_v1.5_224       ssd_resnet34_1200       0.336652
# dtype: float64
